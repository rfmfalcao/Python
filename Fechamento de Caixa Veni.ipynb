# %%
import pyautogui
import pyperclip
import time
import pandas as pd

pyautogui.pause = 5

#entrar na planilha de vendas

pyautogui.hotkey("ctrl", "t")
pyautogui.write("https://drive.google.com/drive/u/1/folders/1D-xRqIPAsbf2IfwR7mU7yAp0XwDIFFW8")
pyautogui.press("enter")

time.sleep(5)

#exportar base de vendas
pyautogui.click(x=454, y=321, button="right")
time.sleep(2)
pyautogui.click(x=481, y=734)
time.sleep(10)
pyautogui.press("enter")

time.sleep(15) #esperar o download

#importar a base de vendas

vendas = pd.read_excel(r"f:\\Cursos\python\Teste.xlsx")
display(vendas)

#calcular faturamento e a quantidade de produtos vendidas
custo = vendas["Total"].sum()
qtd_itens = vendas["Quantidade"].sum()

#enviar e-mail
pyautogui.hotkey("ctrl", "t")
pyperclip.copy("https://mail.google.com/mail/u/0/#inbox")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")

time.sleep(5)

pyautogui.click(x=162, y=255)
time.sleep(10)
pyautogui.write("rfmfalcao@gmail.com")
pyautogui.press("tab")
pyautogui.write("gs.parada@gmail.com")
pyautogui.press("tab")
pyautogui.press("tab")
pyperclip.copy("Relatórios de vendas!")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("tab")

texto  = f""" 
Prezados.
Segue Relatório de vendas:
Foram {qtd_itens} Itens Vendidos
Total Custo: R$ {custo}

Atenciosamente,
VeniBOT
"""

pyperclip.copy(texto)
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("ctrl", "enter")
# Out:
#                                             Unnamed: 0         Custo Unidade  \
# 0                                           Chocolates                   NaN
# 1                                   Bis - Black - 100g                  3.84
# 2                               Bis - Chocolate - 126g                  3.84
# 3                        Bis - Chocolate Branco - 126g                  3.84
# 4                                    Bis - Oreo - 100g                  3.84
# ..                                                 ...                   ...
# 278  Yellow Finger - Piteira de Papel - BIG BROWN c...                  1.82
# 279                         Boveda Umidificador 62% 4g                   NaN
# 280                                                NaN  Total de Itens/Custo
# 281                                                NaN                   NaN
# 282                                  Mix tim autentico                   NaN
#
# ...
